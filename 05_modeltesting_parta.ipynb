# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
from PIL import Image
import os
import matplotlib.pyplot as plt

# ------------------ SETTINGS ------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

test_img_dir = r"C:\Users\nshre\OneDrive\Desktop\Deep_Vision\Dataset\crowd\part_A\test_data\processed_images"
test_density_dir = r"C:\Users\nshre\OneDrive\Desktop\Deep_Vision\Dataset\crowd\part_A\test_data\processed_density"

# ------------------ CSRNet (fresh, untrained) ------------------
class CSRNet(nn.Module):
    def __init__(self):
        super(CSRNet, self).__init__()
        # Frontend (VGG-like)
        self.frontend = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1), nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 3, padding=1), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, padding=1), nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, 3, padding=1), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, padding=1), nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1), nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 512, 3, padding=1), nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1), nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1), nn.ReLU(inplace=True)
        )

        # Backend
        self.backend = nn.Sequential(
            nn.Conv2d(512, 512, 3, dilation=2, padding=2), nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, dilation=2, padding=2), nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, dilation=2, padding=2), nn.ReLU(inplace=True),
            nn.Conv2d(512, 256, 3, dilation=2, padding=2), nn.ReLU(inplace=True),
            nn.Conv2d(256, 128, 3, dilation=2, padding=2), nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, 3, dilation=2, padding=2), nn.ReLU(inplace=True),
            nn.Conv2d(64, 1, 1)
        )

    def forward(self, x):
        x = self.frontend(x)
        x = self.backend(x)
        return x

# ------------------ DATASET CLASS ------------------
class CrowdDataset(Dataset):
    def __init__(self, img_dir, density_dir):
        self.img_dir = img_dir
        self.density_dir = density_dir
        self.img_names = [f for f in os.listdir(img_dir) if f.endswith(".jpg")]

    def __len__(self):
        return len(self.img_names)

    def __getitem__(self, idx):
        img_name = self.img_names[idx]
        img_path = os.path.join(self.img_dir, img_name)
        density_path = os.path.join(self.density_dir, img_name.replace(".jpg", ".npy"))

        img = np.array(Image.open(img_path).convert("RGB"), dtype=np.float32)/255.0
        density = np.load(density_path).astype(np.float32)

        img = torch.tensor(img).permute(2,0,1)  # C,H,W
        density = torch.tensor(density).unsqueeze(0)  # 1,H,W

        return img, density, img_name

# ------------------ LOAD MODEL ------------------
model = CSRNet().to(device)
model.eval()  # evaluation mode

# ------------------ DATA LOADER ------------------
test_dataset = CrowdDataset(test_img_dir, test_density_dir)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# ------------------ TESTING LOOP ------------------
mae = 0.0
mse = 0.0

for images, gts, img_names in test_loader:
    images = images.to(device)
    gts = gts.to(device)

    with torch.no_grad():
        outputs = model(images)

    pred_count = outputs.sum().item()
    gt_count = gts.sum().item()

    mae += abs(pred_count - gt_count)
    mse += (pred_count - gt_count) ** 2

    print(f"{img_names[0]} | Predicted: {pred_count:.2f}, Ground Truth: {gt_count:.2f}")

# ------------------ METRICS ------------------
num_images = len(test_loader)
mae /= num_images
rmse = (mse / num_images) ** 0.5

print(f"\nTest Results - MAE: {mae:.2f}, RMSE: {rmse:.2f}")
# Out:
# IMG_1.jpg | Predicted: 152.71, Ground Truth: 172.00
# IMG_10.jpg | Predicted: 166.58, Ground Truth: 502.00
# IMG_100.jpg | Predicted: 77.54, Ground Truth: 389.00
# IMG_101.jpg | Predicted: 156.18, Ground Truth: 211.00
# IMG_102.jpg | Predicted: 26.39, Ground Truth: 223.00
# IMG_103.jpg | Predicted: 144.05, Ground Truth: 430.00
# IMG_104.jpg | Predicted: 147.52, Ground Truth: 1175.00
# IMG_105.jpg | Predicted: 142.32, Ground Truth: 265.00
# IMG_106.jpg | Predicted: 100.07, Ground Truth: 1232.00
# IMG_107.jpg | Predicted: 66.56, Ground Truth: 289.00
# IMG_23.jpg | Predicted: 202.96, Ground Truth: 429.00
# IMG_24.jpg | Predicted: 137.12, Ground Truth: 553.00
# IMG_25.jpg | Predicted: 147.52, Ground Truth: 243.00
# IMG_26.jpg | Predicted: 27.44, Ground Truth: 497.00
# IMG_27.jpg | Predicted: 168.31, Ground Truth: 760.00
# IMG_28.jpg | Predicted: 150.98, Ground Truth: 423.00
# IMG_29.jpg | Predicted: 147.52, Ground Truth: 309.00
# IMG_3.jpg | Predicted: 57.59, Ground Truth: 297.00
# IMG_30.jpg | Predicted: 81.23, Ground Truth: 307.00
# IMG_31.jpg | Predicted: 131.92, Ground Truth: 250.00
# IMG_32.jpg | Predicted: 147.52, Ground Truth: 959.00
# IMG_33.jpg | Predicted: 124.99, Ground Truth: 474.00
# IMG_34.jpg | Predicted: 12.63, Ground Truth: 89.00
# IMG_35.jpg | Predicted: 93.14, Ground Truth: 566.00
# IMG_36.jpg | Predicted: 92.07, Ground Truth: 1265.00
# IMG_37.jpg | Predicted: 140.68, Ground Truth: 195.00
# IMG_38.jpg | Predicted: 147.52, Ground Truth: 717.00
# IMG_39.jpg | Predicted: 147.52, Ground Truth: 196.00
# IMG_4.jpg | Predicted: 34.58, Ground Truth: 170.00
# IMG_40.jpg | Predicted: 166.58, Ground Truth: 236.00
# IMG_41.jpg | Predicted: 166.58, Ground Truth: 249.00
# IMG_42.jpg | Predicted: 166.58, Ground Truth: 797.00
# IMG_43.jpg | Predicted: 147.52, Ground Truth: 116.00
# IMG_44.jpg | Predicted: 164.84, Ground Truth: 365.00
# IMG_45.jpg | Predicted: 115.96, Ground Truth: 138.00
# IMG_46.jpg | Predicted: 147.52, Ground Truth: 373.00
# IMG_47.jpg | Predicted: 43.84, Ground Truth: 316.00
# IMG_48.jpg | Predicted: 114.59, Ground Truth: 384.00
# IMG_49.jpg | Predicted: 62.23, Ground Truth: 511.00
# IMG_5.jpg | Predicted: 166.58, Ground Truth: 817.00
# IMG_50.jpg | Predicted: 215.10, Ground Truth: 997.00
# IMG_51.jpg | Predicted: 140.68, Ground Truth: 297.00
# IMG_52.jpg | Predicted: 32.38, Ground Truth: 134.00
# IMG_53.jpg | Predicted: 43.15, Ground Truth: 175.00
# IMG_54.jpg | Predicted: 52.58, Ground Truth: 529.00
# IMG_55.jpg | Predicted: 122.71, Ground Truth: 149.00
# IMG_56.jpg | Predicted: 53.35, Ground Truth: 349.00
# IMG_57.jpg | Predicted: 147.52, Ground Truth: 356.00
# IMG_58.jpg | Predicted: 152.71, Ground Truth: 198.00
# IMG_59.jpg | Predicted: 62.50, Ground Truth: 466.00
# IMG_6.jpg | Predicted: 147.52, Ground Truth: 361.00
# IMG_60.jpg | Predicted: 112.42, Ground Truth: 291.00
# IMG_61.jpg | Predicted: 49.27, Ground Truth: 193.00
# IMG_62.jpg | Predicted: 63.56, Ground Truth: 337.00
# IMG_63.jpg | Predicted: 140.58, Ground Truth: 1119.00
# IMG_64.jpg | Predicted: 95.53, Ground Truth: 287.00
# IMG_65.jpg | Predicted: 57.73, Ground Truth: 214.00
# IMG_66.jpg | Predicted: 159.67, Ground Truth: 823.00
# IMG_67.jpg | Predicted: 101.75, Ground Truth: 192.00
# IMG_68.jpg | Predicted: 130.19, Ground Truth: 212.00
# IMG_69.jpg | Predicted: 32.06, Ground Truth: 166.00
# IMG_7.jpg | Predicted: 147.52, Ground Truth: 568.00
# IMG_70.jpg | Predicted: 52.99, Ground Truth: 412.00
# IMG_71.jpg | Predicted: 164.84, Ground Truth: 602.00
# IMG_72.jpg | Predicted: 65.18, Ground Truth: 589.00
# IMG_73.jpg | Predicted: 147.52, Ground Truth: 153.00
# IMG_74.jpg | Predicted: 159.64, Ground Truth: 855.00
# IMG_75.jpg | Predicted: 68.19, Ground Truth: 665.00
# IMG_76.jpg | Predicted: 63.88, Ground Truth: 483.00
# IMG_77.jpg | Predicted: 166.58, Ground Truth: 207.00
# IMG_78.jpg | Predicted: 147.52, Ground Truth: 271.00
# IMG_79.jpg | Predicted: 71.29, Ground Truth: 186.00
# IMG_8.jpg | Predicted: 147.52, Ground Truth: 1326.00
# IMG_80.jpg | Predicted: 149.25, Ground Truth: 157.00
# IMG_81.jpg | Predicted: 52.50, Ground Truth: 356.00
# IMG_82.jpg | Predicted: 42.52, Ground Truth: 217.00
# IMG_83.jpg | Predicted: 166.58, Ground Truth: 218.00
# IMG_84.jpg | Predicted: 147.52, Ground Truth: 122.00
# IMG_85.jpg | Predicted: 124.99, Ground Truth: 97.00
# IMG_86.jpg | Predicted: 159.64, Ground Truth: 579.00
# IMG_87.jpg | Predicted: 147.52, Ground Truth: 417.00
# IMG_88.jpg | Predicted: 166.58, Ground Truth: 86.00
# IMG_89.jpg | Predicted: 89.56, Ground Truth: 382.00
# IMG_9.jpg | Predicted: 166.58, Ground Truth: 371.00
# IMG_90.jpg | Predicted: 99.00, Ground Truth: 2256.00
# IMG_91.jpg | Predicted: 147.52, Ground Truth: 101.00
# IMG_92.jpg | Predicted: 94.55, Ground Truth: 1366.00
# IMG_93.jpg | Predicted: 28.20, Ground Truth: 255.00
# IMG_94.jpg | Predicted: 26.39, Ground Truth: 69.00
# IMG_95.jpg | Predicted: 17.01, Ground Truth: 190.00
# IMG_96.jpg | Predicted: 37.36, Ground Truth: 246.00
# IMG_97.jpg | Predicted: 140.68, Ground Truth: 477.00
# IMG_98.jpg | Predicted: 43.77, Ground Truth: 153.00
# IMG_99.jpg | Predicted: 65.18, Ground Truth: 242.00
#
# Test Results - MAE: 327.38, RMSE: 474.76

# %%
import matplotlib.pyplot as plt

# Assuming 'outputs' is the predicted density map
density_map = outputs.squeeze().cpu().numpy()
plt.imshow(density_map, cmap='jet')
plt.title(f"Predicted count: {density_map.sum():.2f}")
plt.colorbar()
plt.show()
